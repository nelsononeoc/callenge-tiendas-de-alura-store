# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsononeoc/callenge-tiendas-de-alura-store/blob/main/alurastorelatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

archivo1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
archivo2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
archivo3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
archivo4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(archivo1)
tienda2 = pd.read_csv(archivo2)
tienda3 = pd.read_csv(archivo3)
tienda4 = pd.read_csv(archivo4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular la facturación total
tienda1['Total_Facturación'] = tienda1['Precio'] * tienda1['Cantidad de cuotas']
tienda2['Total_Facturación'] = tienda2['Precio'] * tienda2['Cantidad de cuotas']
tienda3['Total_Facturación'] = tienda3['Precio'] * tienda3['Cantidad de cuotas']
tienda4['Total_Facturación'] = tienda4['Precio'] * tienda4['Cantidad de cuotas']

# %%
# Mostrar la facturación total por cada tienda
print("Facturación total de Tienda 1:", tienda1['Total_Facturación'].sum())
print("Facturación total de Tienda 2:", tienda2['Total_Facturación'].sum())
print("Facturación total de Tienda 3:", tienda3['Total_Facturación'].sum())
print("Facturación total de Tienda 4:", tienda4['Total_Facturación'].sum())
# Out:
# Facturación total de Tienda 1: 3422717700.0
# Facturación total de Tienda 2: 3337189200.0
# Facturación total de Tienda 3: 3243816900.0
# Facturación total de Tienda 4: 3098827200.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Calcular ventas por categorías por cada tienda
sales_by_category_tienda1 = tienda1.groupby('Categoría del Producto')['Total_Facturación'].sum()
sales_by_category_tienda2 = tienda2.groupby('Categoría del Producto')['Total_Facturación'].sum()
sales_by_category_tienda3 = tienda3.groupby('Categoría del Producto')['Total_Facturación'].sum()
sales_by_category_tienda4 = tienda4.groupby('Categoría del Producto')['Total_Facturación'].sum()

# %%
# Mostrar ventas por categorías por cada tienda
print("Ventas por categoría - Tienda 1:")
display(sales_by_category_tienda1)
print("\nVentas por categoría - Tienda 2:")
display(sales_by_category_tienda2)
print("\nVentas por categoría - Tienda 3:")
display(sales_by_category_tienda3)
print("\nVentas por categoría - Tienda 4:")
display(sales_by_category_tienda4)
# Out:
# Ventas por categoría - Tienda 1:
# Categoría del Producto
# Artículos para el hogar    3.831680e+07
# Deportes y diversión       1.268837e+08
# Electrodomésticos          1.032376e+09
# Electrónicos               1.290391e+09
# Instrumentos musicales     2.769905e+08
# Juguetes                   4.906280e+07
# Libros                     2.576940e+07
# Muebles                    5.829282e+08
# Name: Total_Facturación, dtype: float64
# Ventas por categoría - Tienda 2:
# Categoría del Producto
# Artículos para el hogar    4.273970e+07
# Deportes y diversión       8.166060e+07
# Electrodomésticos          1.026226e+09
# Electrónicos               1.286644e+09
# Instrumentos musicales     2.944487e+08
# Juguetes                   4.672120e+07
# Libros                     3.141700e+07
# Muebles                    5.273321e+08
# Name: Total_Facturación, dtype: float64
# Ventas por categoría - Tienda 3:
# Categoría del Producto
# Artículos para el hogar    4.472460e+07
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular la calificación pronedio de cada tienda
average_rating_tienda1 = tienda['Calificación'].mean()
average_rating_tienda2 = tienda2['Calificación'].mean()
average_rating_tienda3 = tienda3['Calificación'].mean()
average_rating_tienda4 = tienda4['Calificación'].mean()

# %%
# Mostrar la calificación pronedio de cada tienda
print("Calificación promedio - Tienda 1:", average_rating_tienda1)
print("Calificación promedio - Tienda 2:", average_rating_tienda2)
print("Calificación promedio - Tienda 3:", average_rating_tienda3)
print("Calificación promedio - Tienda 4:", average_rating_tienda4)
# Out:
# Calificación promedio - Tienda 1: 3.976685036032217
# Calificación promedio - Tienda 2: 4.037303942348453
# Calificación promedio - Tienda 3: 4.048325561678677
# Calificación promedio - Tienda 4: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Calcular productos más y menos vendidos por tienda
sales_by_product_tienda1 = tienda1.groupby('Producto')['Total_Facturación'].sum()
sales_by_product_tienda2 = tienda2.groupby('Producto')['Total_Facturación'].sum()
sales_by_product_tienda3 = tienda3.groupby('Producto')['Total_Facturación'].sum()
sales_by_product_tienda4 = tienda4.groupby('Producto')['Total_Facturación'].sum()

# %%
# Mostrar los productos más y menos vendidos por tienda
print("Productos más y menos vendidos - Tienda 1:")
print("Más vendidos:")
display(sales_by_product_tienda1.nlargest(5))
print("\nMenos vendidos:")
display(sales_by_product_tienda1.nsmallest(5))

print("\nProductos más y menos vendidos - Tienda 2:")
print("Más vendidos:")
display(sales_by_product_tienda2.nlargest(5))
print("\nMenos vendidos:")
display(sales_by_product_tienda2.nsmallest(5))

print("\nProductos más y menos vendidos - Tienda 3:")
print("Más vendidos:")
display(sales_by_product_tienda3.nlargest(5))
print("\nMenos vendidos:")
display(sales_by_product_tienda3.nsmallest(5))

print("\nProductos más y menos vendidos - Tienda 4:")
print("Más vendidos:")
display(sales_by_product_tienda4.nlargest(5))
print("\nMenos vendidos:")
display(sales_by_product_tienda4.nsmallest(5))
# Out:
# Productos más y menos vendidos - Tienda 1:
# Más vendidos:
# Producto
# TV LED UHD 4K       451704100.0
# Iphone 15           276559900.0
# Refrigerador        263591900.0
# Smart TV            230818300.0
# Secadora de ropa    216848800.0
# Name: Total_Facturación, dtype: float64
# Menos vendidos:
# Producto
# Cubo mágico 8x8       1490800.0
# Dinosaurio Rex        1642300.0
# Cuerda para saltar    1718700.0
# Set de vasos          3295900.0
# Ajedrez de madera     3869200.0
# Name: Total_Facturación, dtype: float64
# Productos más y menos vendidos - Tienda 2:
# Más vendidos:
# Producto
# Iphone 15        392525900.0
# Refrigerador     298656900.0
# TV LED UHD 4K    284081800.0
# Tablet ABXY      196546100.0
# Smart TV         183417300.0
# Name: Total_Facturación, dtype: float64
# Menos vendidos:
# Producto
# Cubo mágico 8x8       1831100.0
# Cuerda para saltar    2199900.0
# Dinosaurio Rex        2281600.0
# Set de vasos          3362100.0
# Ajedrez de madera     3748700.0
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calcular envío promedio por tienda
average_shipping_tienda1 = tienda['Costo de envío'].mean()
average_shipping_tienda2 = tienda2['Costo de envío'].mean()
average_shipping_tienda3 = tienda3['Costo de envío'].mean()
average_shipping_tienda4 = tienda4['Costo de envío'].mean()

# %%
# Mostrar el envío promedio por tienda
print("Envío promedio - Tienda 1:", average_shipping_tienda1)
print("Envío promedio - Tienda 2:", average_shipping_tienda2)
print("Envío promedio - Tienda 3:", average_shipping_tienda3)
print("Envío promedio - Tienda 4:", average_shipping_tienda4)
# Out:
# Envío promedio - Tienda 1: 26018.60958033065
# Envío promedio - Tienda 2: 25216.235693090293
# Envío promedio - Tienda 3: 24805.680373039424
# Envío promedio - Tienda 4: 23459.457167090754
